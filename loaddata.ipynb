# %%
import pandas as pd
import requests
import json

# %%
df = pd.read_csv('agriculture_dataset.csv')
# df.head()
# print(df.columns)
#print(df['Chlorophyll_Content'])
#print(df['Crop_Stress_Indicator'])
df = df.drop(['High_Resolution_RGB','Multispectral_Images','Thermal_Images','Temporal_Images','Spatial_Resolution','Ground_Truth_Segmentation','Bounding_Boxes'],axis=1)
df.head()
# Out:
#    GPS_Coordinates  Field_Boundaries  Elevation_Data  Canopy_Coverage  \
# 0           201538                 3       28.207634         8.046926
# 1           215854                 3       82.335147       147.512332
# 2           890802                 3       83.865629        30.246527
# 3           605584                 3       20.747905         6.857820
# 4           871732                 3       22.588815        26.168558
#
#        NDVI      SAVI  Chlorophyll_Content  Leaf_Area_Index  \
# 0  0.676945  0.475536             0.829063         3.107188
# 1  0.414781  0.325712             0.435861         1.287952
# 2  0.723610  0.511144             1.001452         1.229495
# 3  0.405611  0.162857             0.962720         0.995907
# 4  0.465992  0.269888             2.111205         0.438672
#
#    Crop_Stress_Indicator  Temperature  ...  Organic_Matter  Pest_Hotspots  \
# 0                     79    24.627325  ...        2.126335              0
# ...
